# %% [markdown]
# #### Tratamento e padronização dos dados

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df_arrivals = pd.read_csv('data/International Arrivals - Number of Tourists/international_arrivals_number_tourists.csv', skiprows=4)
df_paises = pd.read_csv('continentes.csv')

df_arrivals.head()
# Out:
#                   Country Name Country Code  \
# 0                        Aruba          ABW
# 1  Africa Eastern and Southern          AFE
# 2                  Afghanistan          AFG
# 3   Africa Western and Central          AFW
# 4                       Angola          AGO
#
#                               Indicator Name Indicator Code  1960  1961  1962  \
# 0  International tourism, number of arrivals    ST.INT.ARVL   NaN   NaN   NaN
# 1  International tourism, number of arrivals    ST.INT.ARVL   NaN   NaN   NaN
# 2  International tourism, number of arrivals    ST.INT.ARVL   NaN   NaN   NaN
# 3  International tourism, number of arrivals    ST.INT.ARVL   NaN   NaN   NaN
# 4  International tourism, number of arrivals    ST.INT.ARVL   NaN   NaN   NaN
#
#    1963  1964  1965  ...          2017          2018          2019  2020  \
# 0   NaN   NaN   NaN  ...  1.863000e+06  1.897000e+06  1.951000e+06   NaN
# 1   NaN   NaN   NaN  ...  3.825835e+07  4.118915e+07  3.982670e+07   NaN
# 2   NaN   NaN   NaN  ...           NaN           NaN           NaN   NaN
# 3   NaN   NaN   NaN  ...           NaN           NaN           NaN   NaN
# 4   NaN   NaN   NaN  ...  2.610000e+05  2.180000e+05  2.180000e+05   NaN
#
#    2021  2022  2023  2024  2025  Unnamed: 70
# 0   NaN   NaN   NaN   NaN   NaN          NaN
# 1   NaN   NaN   NaN   NaN   NaN          NaN
# 2   NaN   NaN   NaN   NaN   NaN          NaN
# 3   NaN   NaN   NaN   NaN   NaN          NaN
# 4   NaN   NaN   NaN   NaN   NaN          NaN
#
# [5 rows x 71 columns]

# %%
df_arrivals.columns
# Out:
# Index(['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code',
#        '1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
#        '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
#        '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
#        '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
#        '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
#        '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
#        '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022',
#        '2023', '2024', '2025', 'Unnamed: 70'],
#       dtype='object')

# %%
#Removendo colunas desnecessarias
df_arrivals = df_arrivals.drop(columns=['Indicator Name', 'Indicator Code', 'Unnamed: 70'], axis=1)
df_arrivals.columns
# Out:
# Index(['Country Name', 'Country Code', '1960', '1961', '1962', '1963', '1964',
#        '1965', '1966', '1967', '1968', '1969', '1970', '1971', '1972', '1973',
#        '1974', '1975', '1976', '1977', '1978', '1979', '1980', '1981', '1982',
#        '1983', '1984', '1985', '1986', '1987', '1988', '1989', '1990', '1991',
#        '1992', '1993', '1994', '1995', '1996', '1997', '1998', '1999', '2000',
#        '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009',
#        '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018',
#        '2019', '2020', '2021', '2022', '2023', '2024', '2025'],
#       dtype='object')

# %%
df_arrivals.rename(columns={
    "Country Name": "País",
    "Country Code": "Sigla",
}, inplace=True)

df_arrivals.head()
# Out:
#                           País Sigla  1960  1961  1962  1963  1964  1965  \
# 0                        Aruba   ABW   NaN   NaN   NaN   NaN   NaN   NaN
# 1  Africa Eastern and Southern   AFE   NaN   NaN   NaN   NaN   NaN   NaN
# 2                  Afghanistan   AFG   NaN   NaN   NaN   NaN   NaN   NaN
# 3   Africa Western and Central   AFW   NaN   NaN   NaN   NaN   NaN   NaN
# 4                       Angola   AGO   NaN   NaN   NaN   NaN   NaN   NaN
#
#    1966  1967  ...          2016          2017          2018          2019  \
# 0   NaN   NaN  ...  1.758000e+06  1.863000e+06  1.897000e+06  1.951000e+06
# 1   NaN   NaN  ...  3.764589e+07  3.825835e+07  4.118915e+07  3.982670e+07
# 2   NaN   NaN  ...           NaN           NaN           NaN           NaN
# 3   NaN   NaN  ...  1.315078e+07           NaN           NaN           NaN
# 4   NaN   NaN  ...  3.970000e+05  2.610000e+05  2.180000e+05  2.180000e+05
#
#    2020  2021  2022  2023  2024  2025
# 0   NaN   NaN   NaN   NaN   NaN   NaN
# 1   NaN   NaN   NaN   NaN   NaN   NaN
# 2   NaN   NaN   NaN   NaN   NaN   NaN
# 3   NaN   NaN   NaN   NaN   NaN   NaN
# 4   NaN   NaN   NaN   NaN   NaN   NaN
#
# [5 rows x 68 columns]

# %%
cols_anos = [col for col in df_arrivals.columns if col.isdigit() and 1980 <= int(col) <= 2025]
contagem = df_arrivals[cols_anos].notna().sum()
total_paises = len(df_arrivals)


plt.ylim(0, total_paises * 1.1)
plt.plot(contagem.index.astype(int), contagem.values, label="Países com dados")
anos = contagem.index.astype(int)
plt.xticks(anos[anos >= 1980][::2], rotation=45)  # de 2 em 2 anos
plt.axhline(y=total_paises, linestyle='--', label="Total de países")
plt.xlabel("Ano")
plt.ylabel("Número de países com dados")
plt.title("Disponibilidade de dados por ano")
plt.legend()
plt.show()

# %%
#selecionando apenas o intervalo com maior quantidade de dados, verificar se 2000 
cols_anos = [col for col in df_arrivals.columns if col.isdigit() and 2000 <= int(col) <= 2020]
cols_finais = ['País', 'Sigla'] + cols_anos
df_arrivals = df_arrivals[cols_finais]

#df_arrivals = df_arrivals.merge(
#    df_paises[['Sigla', 'Continente']],
#    left_on='Sigla',
#    right_on='Sigla',
#    how='left'
#)

#adicionando continentes e removendo os nao paises
df_arrivals = df_arrivals.merge(
    df_paises[['Sigla', 'Continente']],
    on='Sigla',
    how='inner'
)

#cols = ['País', 'sigla', 'Regiao', 'sub-region'] + [col for col in df_final.columns if col not in ['Country Name', 'Country Code', 'region', 'sub-region']]
cols = ['País', 'Sigla', 'Continente'] + [col for col in df_arrivals.columns if col not in ['País', 'Sigla', 'Continente']]

df_arrivals = df_arrivals[cols]

#df_arrivals.rename(columns={"region": "Continente"}, inplace=True)

df_arrivals.head()
# Out:
#           País Sigla Continente        2000        2001        2002  \
# 0        Aruba   ABW        NaN   1211000.0   1178000.0   1225000.0
# 1  Afghanistan   AFG         AS         NaN         NaN         NaN
# 2       Angola   AGO         AF     51000.0     67000.0     91000.0
# 3      Albania   ALB         EU    317000.0    354000.0    470000.0
# 4      Andorra   AND         EU  10991000.0  11351000.0  11507000.0
#
#          2003        2004        2005        2006  ...       2011       2012  \
# 0   1184000.0   1304000.0   1286000.0   1285000.0  ...  1469000.0  1481000.0
# 1         NaN         NaN         NaN         NaN  ...        NaN        NaN
# 2    107000.0    194000.0    210000.0    121000.0  ...   481000.0   528000.0
# 3    557000.0    645000.0    748000.0    937000.0  ...  2932000.0  3514000.0
# 4  11601000.0  11668000.0  11049000.0  10737000.0  ...  7983000.0  7900000.0
#
#         2013       2014       2015       2016       2017       2018  \
# 0  1667000.0  1739000.0  1832000.0  1758000.0  1863000.0  1897000.0
# 1        NaN        NaN        NaN        NaN        NaN        NaN
# 2   650000.0   595000.0   592000.0   397000.0   261000.0   218000.0
# 3  3256000.0  3673000.0  4131000.0  4736000.0  5118000.0  5927000.0
# 4  7676000.0  7797000.0  7850000.0  8025000.0  8152000.0  8328000.0
#
#         2019       2020
# 0  1951000.0        NaN
# 1        NaN        NaN
# 2   218000.0        NaN
# 3  6406000.0  2658000.0
# 4  8235000.0  5207000.0
#
# [5 rows x 24 columns]

# %%
cols_anos = sorted(
    [col for col in df_arrivals.columns if col.isdigit() and int(col) > 2000],
    key=int
)

contagem_linhas = df_arrivals[cols_anos].notna().sum(axis=1)

# Criterio de remoção: se tiver mais de 14 dados não remove, ajustar se necessario
mask = contagem_linhas >= 14

removidos = df_arrivals.loc[~mask, ['País'] + cols_anos].copy()
removidos['qtd_dados'] = contagem_linhas[~mask]

# remove todos os paises que não tem mais de 14 anos com dados
df_arrivals = df_arrivals[mask]


#contagem = df_arrivals[cols_anos].notna().sum()
#total_paises = len(df_arrivals)

removidos

#df_arrivals
# Out:
#                           País          2001       2002          2003  \
# 1                  Afghanistan           NaN        NaN           NaN
# 5         United Arab Emirates           NaN        NaN           NaN
# 28           Brunei Darussalam  8.400000e+05   891000.0  9.440000e+05
# 30                    Botswana  1.451000e+06  1485000.0  1.592000e+06
# 34                       Chile           NaN        NaN           NaN
# 39                 Congo, Rep.           NaN        NaN           NaN
# 50                    Djibouti  2.160000e+04    22500.0  2.320000e+04
# 64               Faroe Islands           NaN        NaN           NaN
# 66                       Gabon  2.360000e+05   269000.0  2.340000e+05
# 70                   Gibraltar           NaN        NaN           NaN
# 74           Equatorial Guinea           NaN        NaN           NaN
# 77                   Greenland           NaN        NaN           NaN
# 87                 Isle of Man           NaN        NaN           NaN
# 91                        Iraq  1.270000e+05        NaN           NaN
# 102                   Kiribati  1.450000e+04   119500.0  1.301000e+05
# 108                    Liberia           NaN        NaN           NaN
# 109                      Libya  9.530000e+05   858000.0  9.580000e+05
# 118   St. Martin (French part)           NaN        NaN           NaN
# 122                 Madagascar           NaN        NaN           NaN
# 134                 Mauritania           NaN        NaN           NaN
# 146                      Nauru           NaN        NaN           NaN
# 149                   Pakistan  5.000000e+05   498000.0  5.010000e+05
# 154           Papua New Guinea           NaN        NaN           NaN
# 157  Korea, Dem. People's Rep.           NaN        NaN           NaN
# 162                      Qatar           NaN        NaN           NaN
# 171               Sierra Leone           NaN        NaN           NaN
# 174         Somalia, Fed. Rep.           NaN        NaN           NaN
# 176                South Sudan           NaN        NaN           NaN
# 179            Slovak Republic           NaN        NaN           NaN
# 186   Turks and Caicos Islands           NaN        NaN           NaN
# 190                 Tajikistan  5.200000e+03        NaN           NaN
# 191               Turkmenistan           NaN        NaN           NaN
# 211                Yemen, Rep.           NaN        NaN           NaN
#
#              2004          2005          2006          2007       2008  \
# 1             NaN           NaN           NaN           NaN        NaN
# 5             NaN           NaN           NaN           NaN        NaN
# 28            NaN  8.150000e+05  8.360000e+05  8.770000e+05        NaN
# 30   1.727000e+06  1.684000e+06  1.642000e+06  1.965000e+06  2344000.0
# 34            NaN           NaN           NaN           NaN  3713000.0
# 39            NaN           NaN           NaN           NaN        NaN
# 50   2.630000e+04  3.020000e+04  3.950000e+04  4.000000e+04    54000.0
# 64            NaN           NaN           NaN           NaN        NaN
# 66   3.510000e+05  5.260000e+05           NaN           NaN        NaN
# 70            NaN           NaN           NaN           NaN        NaN
# 74            NaN           NaN           NaN           NaN        NaN
# 77            NaN           NaN           NaN           NaN        NaN
# 87            NaN           NaN           NaN           NaN        NaN
# 91            NaN           NaN           NaN           NaN   864000.0
# 102  6.390000e+04  5.020000e+04  1.080000e+04  3.230000e+04        NaN
# 211        NaN  ...  1282000.0   1323000.0  1.218000e+06  3.980000e+05
#
#              2016        2017        2018        2019          2020  qtd_dados
# 1             NaN         NaN         NaN         NaN           NaN          0
# 5    2.089400e+07  21805000.0  23092000.0  25282000.0  8.084000e+06          6
# 28   4.257000e+06   4316000.0   4521000.0   4449000.0  1.071000e+06         11
# 30   1.712000e+06   1775000.0   1830000.0         NaN           NaN         12
# 34   6.712000e+06   7621000.0   6603000.0   5431000.0           NaN         12
# 39   2.130000e+05    151000.0    158000.0         NaN           NaN          9
# 50            NaN         NaN         NaN         NaN           NaN         13
# 64            NaN         NaN         NaN         NaN           NaN          0
# 66            NaN         NaN         NaN         NaN           NaN          5
# 70            NaN         NaN         NaN         NaN           NaN          0
# 74            NaN         NaN         NaN         NaN           NaN          0
# 77            NaN         NaN         NaN         NaN           NaN          0
# 87            NaN         NaN         NaN         NaN           NaN          0
# 91            NaN         NaN         NaN         NaN           NaN          7
# 102  7.600000e+03      7500.0      9000.0     12000.0           NaN         13
# 108           NaN         NaN         NaN         NaN           NaN          0
# 109           NaN         NaN         NaN         NaN           NaN          6
# 118           NaN         NaN         NaN         NaN           NaN          0
# 122  3.330000e+05    285000.0    360000.0    486000.0  8.710000e+04          6
# 134           NaN         NaN         NaN         NaN           NaN          0
# 146           NaN         NaN         NaN         NaN           NaN          0
# 149           NaN         NaN         NaN         NaN           NaN         12
# 154  1.980000e+05    182000.0    195000.0    211000.0  3.900000e+04         13
# 157           NaN         NaN         NaN         NaN           NaN          0
# 162  2.938000e+06   2256000.0   1819000.0   2136500.0  5.820000e+05         12
# 171  6.000000e+04     59000.0     66000.0     71000.0           NaN          8
# 174           NaN         NaN         NaN         NaN           NaN          0
# 176           NaN         NaN         NaN         NaN           NaN          0
# 179  1.737600e+07  15406000.0  15299000.0         NaN           NaN          6
# 186  1.296000e+06   1243000.0   1463000.0   1599000.0  3.704000e+05         13
# 190  3.440000e+05    431000.0   1035000.0         NaN           NaN         12
# 191           NaN         NaN         NaN         NaN           NaN          0
# 211           NaN         NaN         NaN         NaN           NaN          6
#
# [33 rows x 22 columns]

# %%
#verificando se existe algum pais com valores negativos
df_arrivals[df_arrivals[cols_anos].lt(0).any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [País, Sigla, Continente, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020]
# Index: []
#
# [0 rows x 24 columns]

# %%
df_arrivals[cols_anos].isna().sum().sum()
# Out:
# np.int64(171)

# %%
#Exportação dos dados filtrados
import os

# nome do arquivo
caminho_saida = "data/International Arrivals - Number of Tourists/international_arrivals_number_tourists.csv"

# salvar
df_arrivals.to_csv(caminho_saida, index=False, encoding='utf-8-sig')

# %% [markdown]
# ### **Estrutura de dados**
#
# | Coluna        | Tipo   | Descrição                                                   |
# |--------------|--------|-------------------------------------------------------------|
# | País         | String | Nome do país                                                |
# | Continente   | String | Continente ao qual o país pertence                                              |
# | Sigla        | String | Código ISO alpha-3 do país                                  |
# | 2000 a 2020  | numérico  | Número total de chegadas de turistas internacionais no ano  |
